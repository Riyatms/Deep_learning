# %% [markdown]
# # <span style = "color:IndianRed; font-size:40px"> Brain Tumor Classification (MRI)</span>

# %% [markdown]
# ***

# %% [markdown]
# A Brain tumor is considered as one of the aggressive diseases, among children and adults. Brain tumors account for 85 to 90 percent of all primary Central Nervous System(CNS) tumors. Every year, around 11,700 people are diagnosed with a brain tumor. The 5-year survival rate for people with a cancerous brain or CNS tumor is approximately 34 percent for men and36 percent for women. Brain Tumors are classified as: Benign Tumor, Malignant Tumor, Pituitary Tumor, etc. Proper treatment, planning, and accurate diagnostics should be implemented to improve the life expectancy of the patients. The best technique to detect brain tumors is Magnetic Resonance Imaging (MRI). A huge amount of image data is generated through the scans. These images are examined by the radiologist. A manual examination can be error-prone due to the level of complexities involved in brain tumors and their properties.
# Application of automated classification techniques using Machine Learning(ML) and Artificial Intelligence(AI)has consistently shown higher accuracy than manual classification. Hence, proposing a system performing detection and classification by using Deep Learning Algorithms using ConvolutionNeural Network (CNN), Artificial Neural Network (ANN), and TransferLearning (TL) would be helpful to doctors all around the world.

# %% [markdown]
# ## Context

# %% [markdown]
# Brain Tumors are complex.  There are lot of abnormalities in the sizes and location of the brain tumor(s). This makes it really difficult for complete understanding of the nature of the tumor. Also, a professional Neurosurgeon is required for MRI analysis. Often times in developing countries the lack of skillful doctors and lack of knowledge about tumors makes it really challenging an time-consuming to generate reports from MRI. So an automated system can solve this problem.

# %% [markdown]
# ## Definition

# %% [markdown]
# To Detect and Classify Brain Tumor using CNN, and TL; as an asset of Deep Learning and to examine the tumor position(segmentation).

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from tensorflow import keras
from sklearn.utils import shuffle
from skimage.transform import resize
from sklearn.ensemble import RandomForestClassifier
import glob
# Out:
# WARNING:tensorflow:From C:\Users\sheri\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Fetch the training Data

# %% [markdown]
# #### Use glob

# %% [markdown]
# The data contains 4 subclasses. Store all 4 in different variables

# %%
glioma_tumor=glob.glob("Brain_tumor/Training/glioma_tumor/*.jpg")[0:50]
no_tumor=glob.glob('Brain_tumor/Training/no_tumor/*.jpg')[0:50]
meningioma_tumor=glob.glob('Brain_tumor/Training/meningioma_tumor/*.jpg')[0:50]
pituitary_tumor=glob.glob('Brain_tumor/Training/pituitary_tumor/*.jpg')[0:50]

# %%
len(glioma_tumor)
# Out:
# 50

# %% [markdown]
# ### Fetch the testing data

# %%
glioma_tumor_test=glob.glob("Brain_tumor/Testing/glioma_tumor/*.jpg")
no_tumor_test=glob.glob('Brain_tumor/Testing/no_tumor/*.jpg')
meningioma_tumor_test=glob.glob('Brain_tumor/Testing/meningioma_tumor/*.jpg')
pituitary_tumor_test=glob.glob('Brain_tumor/Testing/pituitary_tumor/*.jpg')

# %% [markdown]
# ### Find the number of images of all classes in the Training set

# %%
print('Number of images in Training set are:')
print(f'Glioma: {len(glioma_tumor)}')
print(f'Meninglioma: {len(meningioma_tumor)}')
print(f'Glioma: {len(no_tumor)}')
print(f'Glioma: {len(pituitary_tumor)}')
# Out:
# Number of images in Training set are:
# Glioma: 50
# Meninglioma: 50
# Glioma: 50
# Glioma: 50

# %% [markdown]
# ### Find the number of images of all classes in the testing set

# %%
print('Number of images in Testing set are:')
print(f'Glioma: {len(glioma_tumor_test)}')
print(f'Meninglioma: {len(meningioma_tumor_test)}')
print(f'Glioma: {len(no_tumor_test)}')
print(f'Glioma: {len(pituitary_tumor_test)}')
# Out:
# Number of images in Testing set are:
# Glioma: 24
# Meninglioma: 24
# Glioma: 24
# Glioma: 24

# %% [markdown]
# ### Store all the images inside a list and create a list with the corresponding labels

# %% [markdown]
# ### For Training set

# %%
image=[]
label=[]

for i in glioma_tumor:
    img=plt.imread(i)
    image.append(img)
    label.append(0)
    
for i in meningioma_tumor:
    img=plt.imread(i)
    image.append(img)
    label.append(1)
    
for i in no_tumor:
    img=plt.imread(i)
    image.append(img)
    label.append(2)
    
for i in pituitary_tumor:
    img=plt.imread(i)
    image.append(img)
    label.append(3)

# %% [markdown]
# ### For Testing set

# %%
image_test=[]
label_test=[]

for i in glioma_tumor_test:
    img=plt.imread(i)
    image_test.append(img)
    label_test.append(0)
    
for i in meningioma_tumor_test:
    img=plt.imread(i)
    image_test.append(img)
    label_test.append(1)
    
for i in no_tumor_test:
    img=plt.imread(i)
    image_test.append(img)
    label_test.append(2)
    
for i in pituitary_tumor_test:
    img=plt.imread(i)
    image_test.append(img)
    label_test.append(3)

# %% [markdown]
# ### Shuffle both image list and label list (In both Training and testing set)

# %% [markdown]
# #### Use shuffle function from sklearn utils

# %%
image,label=shuffle(image,label,random_state=100)

# %%
image_test,label_test=shuffle(image_test,label_test,random_state=100)

# %% [markdown]
# ### Plot a few images from our shuffled list with its corresponding label (Either from training or test set)

# %%
dic={0:'Glioma',1:'Meningioma',2:'No Tumor',3:'Pituatary'}

# %%
plt.figure(figsize=(10,10))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(image[i])
    plt.title(dic[label[i]])
plt.tight_layout()

# %% [markdown]
# ### Check the shape of the first 10 images in our list (Either from training or test set)

# %%
for i in range(10):
     print(image[i].shape)
# Out:
# (225, 225, 3)
# (442, 442, 3)
# (512, 512, 3)
# (512, 512, 3)
# (630, 630, 3)
# (512, 512, 3)
# (630, 630, 3)
# (512, 512, 3)
# (512, 512, 3)
# (512, 512, 3)

# %% [markdown]
# ### Reshape the images to 224x224( For both training and testing set)

# %% [markdown]
# Also reassign them to new variables named X_train and X_test and convert them to a numpy array

# %%
x_train=[]

for i in image:
    x_train.append(resize(i,(244,244,3)))
x_train=np.array(x_train)

# %%
x_test=[]

for i in image_test:
    x_test.append(resize(i,(244,244,3)))
x_test=np.array(x_test)

# %% [markdown]
# ### Create numpy arrays named y_train and y_test from our training and testing label lists we created earlier

# %%
y_train = np.array(label)
y_test = np.array(label_test)

# %% [markdown]
# ### Plot some of our reshaped images

# %%
plt.figure(figsize=(10,10))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(x_train[i])
    plt.title(dic[y_train[i]])
plt.tight_layout()

# %% [markdown]
# ### Check the shape of X_train and X_test and y_train and y_test

# %%
print(f'Shape of x_train is: {x_train.shape}')
print(f'Shape of x_test is: {x_test.shape}')
print(f'Shape of y_train is: {y_train.shape}')
print(f'Shape of y_test is: {y_test.shape}')
# Out:
# Shape of x_train is: (200, 244, 244, 3)
# Shape of x_test is: (96, 244, 244, 3)
# Shape of y_train is: (200,)
# Shape of y_test is: (96,)

# %% [markdown]
# ### Create a keras Sequential model with convolution layers, Flatten and  Hidden layers

# %%
model = RandomForestClassifier()

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(16, (3,3), activation = 'relu', input_shape = (244, 244, 3)),
    keras.layers.MaxPool2D(),
    
    keras.layers.Conv2D(32,(3,3), activation = 'relu'),
    keras.layers.MaxPool2D(),
    
    keras.layers.Flatten(),
    
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(4, activation = 'softmax')
])
# Out:
# WARNING:tensorflow:From C:\Users\sheri\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\sheri\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# ### Compile the model

# %% [markdown]
# #### Use 'sparse_categorical_crossentropy' for loss

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\sheri\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### Check the summary of our model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 242, 242, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 121, 121, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 119, 119, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 59, 59, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 111392)            0
#
#  dense (Dense)               (None, 64)                7129152
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 7134500 (27.22 MB)
# Trainable params: 7134500 (27.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model.
# Make sure to include a validation data with validation_split

# %%
model.fit(x_train,y_train,epochs=5,validation_split=0.05)
# Out:
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\sheri\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\sheri\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 6/6 [==============================] - 8s 798ms/step - loss: 4.9075 - accuracy: 0.2632 - val_loss: 2.5760 - val_accuracy: 0.4000
# Epoch 2/5
# 6/6 [==============================] - 4s 700ms/step - loss: 1.6925 - accuracy: 0.4737 - val_loss: 1.3042 - val_accuracy: 0.4000
# Epoch 3/5
# 6/6 [==============================] - 5s 850ms/step - loss: 0.9093 - accuracy: 0.6474 - val_loss: 0.9966 - val_accuracy: 0.7000
# Epoch 4/5
# 6/6 [==============================] - 5s 815ms/step - loss: 0.7813 - accuracy: 0.7789 - val_loss: 0.8497 - val_accuracy: 0.7000
# Epoch 5/5
# 6/6 [==============================] - 4s 690ms/step - loss: 0.6030 - accuracy: 0.8789 - val_loss: 0.6632 - val_accuracy: 0.7000

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(x_train,y_train)
# Out:
# 7/7 [==============================] - 1s 133ms/step - loss: 0.4874 - accuracy: 0.9000
# [0.48744574189186096, 0.8999999761581421]

# %% [markdown]
# ### Make predictions with X_test

# %%
prediction=model.predict(x_test)
# Out:
# 3/3 [==============================] - 0s 158ms/step

# %% [markdown]
# ### Use np.argmax to fetch indices of max element of the array

# %% [markdown]
# Store the values in a list

# %%
y_pred=[np.argmax(i) for i in prediction]

# %%
y_pred[:5]
# Out:
# [0, 2, 2, 2, 1]

# %% [markdown]
# ### Plot X_test with label from our prediction

# %%
plt.figure(figsize=(10,10))
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.imshow(x_train[i])
    plt.title(dic[y_pred[i]])
plt.tight_layout()

# %% [markdown]
# ### Visualise confusion matrix on a heatmap

# %%
sns.heatmap(confusion_matrix(y_pred,y_test),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ***
